# %% [markdown]
# # <font color='blue'>Jogo dos 7 Erros - Identificar e Corrigir Erros em Visualizações de Dados</font>

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "André Luiz Colombo"
# Out:
# Author: André Luiz Colombo

# %% [markdown]
# ## Visualização 1
#
# Problema: Gráfico de Barras com Escala Inapropriada.
#
# Erro: Utilizar um eixo que não se inicia em zero, o que pode distorcer a percepção dos dados. Neste caso, o eixo Y começa em 40 em vez de 0, fazendo com que as diferenças entre as categorias pareçam maiores do que realmente são, podendo levar a interpretações equivocadas sobre a magnitude dos valores.

# %%
# Dados de exemplo
categorias = ['Categoria A', 'Categoria B', 'Categoria C', 'Categoria D']
valores = [55, 49, 90, 76]

# Criando o gráfico de barras
plt.figure(figsize = (10, 6))
plt.bar(categorias, valores, color = 'skyblue')

# Definindo uma escala para o eixo Y
plt.ylim(40, 100) 

# Labels
plt.title('Gráfico de Barras')
plt.xlabel('Categorias')
plt.ylabel('Valores')
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# > Versão Corrigida:

# %%
# Dados de exemplo
categorias = ['Categoria A', 'Categoria B', 'Categoria C', 'Categoria D']
valores = [55, 49, 90, 76]

# Criando o gráfico de barras corrigido
plt.figure(figsize=(10, 6))
plt.bar(categorias, valores, color='skyblue')

# Definindo uma escala apropriada para o eixo Y (começando em 0)
plt.ylim(0, 100)  # Iniciando o eixo Y em 0

plt.title('Gráfico de Barras com Escala Correta')
plt.xlabel('Categorias')
plt.ylabel('Valores')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Visualização 2
#
# Problema: Gráfico de Pizza com Muitas Categorias.
#
# Aplicar um gráfico de pizza em cenários com muitas categorias, o que compromete a legibilidade e dificulta a comparação entre as partes. Esse excesso de informações pode causar confusão visual e tornar menos clara a interpretação das proporções entre os grupos apresentados.

# %%
# Dados de exemplo
categorias = ['Cat A', 'Cat B', 'Cat C', 'Cat D', 'Cat E', 'Cat F', 'Cat G', 'Cat H', 'Cat I', 'Cat J', 'Cat K', 'Cat L']
valores = [5, 7, 4, 6, 7, 8, 5, 9, 3, 2, 4, 5]

# Criando o gráfico de pizza
plt.figure(figsize = (10, 8))
plt.pie(valores, labels = categorias, autopct = '%1.1f%%', startangle = 140)

# Labels
plt.title('Gráfico de Pizza')
plt.show()

# %% [markdown]
# > Versão Corrigida:

# %%
# Criando um gráfico de barras horizontal como alternativa ao gráfico de pizza para melhorar a visualização
plt.figure(figsize = (10, 8))
plt.barh(categorias, valores, color = 'lightblue')
plt.xlabel('Valores')
plt.title('Gráfico de Barras Horizontal - Melhor para Muitas Categorias')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ## Visualização 3
#
# Problema: Gráfico de Linhas para Dados Categóricos.
#
# Erro: Empregar um gráfico de linhas para representar categorias sem ordenação natural, criando a falsa impressão de continuidade ou sequência lógica entre os dados. Esse tipo de visualização pode induzir interpretações incorretas, sugerindo relações que não existem entre as categorias apresentadas.

# %%
# Dados categóricos 
categorias = ['Categoria A', 'Categoria B', 'Categoria C', 'Categoria D']
valores = [20, 35, 30, 45]

# Mapeando categorias para um valor numérico para poder plotar no gráfico de linhas
categorias_map = range(len(categorias))

# Cria o plot
plt.figure(figsize = (10, 6))
plt.plot(categorias_map, valores, marker = 'o', linestyle = '-', color = 'b')

# Ajustando os rótulos do eixo x para mostrar as categorias
plt.xticks(categorias_map, categorias)

# Labels
plt.title('Gráfico de Linhas')
plt.xlabel('Categorias')
plt.ylabel('Valores')
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# > Versão Corrigida:

# %%
# Criando um gráfico de barras para representar melhor os dados categóricos
plt.figure(figsize = (10, 6))
plt.bar(categorias, valores, color = 'blue')
plt.title('Gráfico de Barras Para Dados Categóricos')
plt.xlabel('Categorias')
plt.ylabel('Valores')
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# ## Visualização 4
#
# Problema: Uso de Cores Não Intuitivas
#
# Erro: Adotar uma paleta de cores com baixo contraste ou sem coerência semântica com os dados apresentados. Nesse caso, as cores escolhidas não representam de forma intuitiva a variação nos níveis de satisfação de “Muito Satisfeito” a “Muito Insatisfeito”, dificultando a leitura imediata e a compreensão da progressão entre as categorias.

# %%
# Dados de exemplo
categorias = ['Muito Satisfeito', 'Satisfeito', 'Neutro', 'Insatisfeito', 'Muito Insatisfeito']
valores = [25, 35, 20, 15, 5]

# Definindo uma paleta de cores
cores = ['grey', 'orange', 'blue', 'yellow', 'green']

# Cria o plot
plt.figure(figsize = (10, 6))
plt.bar(categorias, valores, color = cores)

# Labels
plt.title('Nível de Satisfação (%)')
plt.xlabel('Nível de Satisfação')
plt.ylabel('Porcentagem (%)')
plt.xticks(rotation = 45)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# > Versão Corrigida:

# %%
# Corrigindo a paleta de cores para seguir uma ordem lógica de sentimentos
cores_corrigidas = ['green', 'lightgreen', 'yellow', 'orange', 'red']

# Criando o gráfico de barras com a nova paleta de cores
plt.figure(figsize = (10, 6))
plt.bar(categorias, valores, color = cores_corrigidas)

plt.title('Nível de Satisfação (%)')
plt.xlabel('Nível de Satisfação')
plt.ylabel('Porcentagem (%)')
plt.xticks(rotation = 45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Visualização 5
#
# Problema: Sobrecarga de Informação.
#
# Erro: Concentrar muitas informações e recursos visuais em um único gráfico, comprometendo sua clareza. Neste caso, a combinação de várias linhas, estilos e marcadores para representar diferentes séries (como vendas e custos) torna a leitura mais difícil e prejudica a comparação entre os dados. Essa complexidade pode confundir o público e dificultar a identificação de padrões, tendências ou diferenças relevantes.

# %%
# Dados de exemplo
data = {
    'Mes': ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho'],
    'Vendas A': [200, 150, 300, 250, 270, 300],
    'Vendas B': [220, 170, 310, 265, 290, 320],
    'Vendas C': [210, 160, 305, 255, 280, 310],
    'Custo A': [100, 80, 150, 130, 140, 150],
    'Custo B': [110, 90, 155, 135, 145, 155],
    'Custo C': [105, 85, 152, 132, 138, 152],
}

# Cria o dataframe
df = pd.DataFrame(data)

# Plot
plt.figure(figsize = (14, 8))

# Loop para a formatação
for column in df.columns[1:]:
    if 'Vendas' in column:
        plt.plot(df['Mes'], df[column], marker = 'o', linestyle = '-', label = column)
    else:
        plt.plot(df['Mes'], df[column], marker = 'x', linestyle = '--', label = column)

# Labels
plt.title('Vendas x Custo')
plt.xlabel('Mês')
plt.ylabel('Valor')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# > Versão Corrigida:

# %%
# Simplificando o gráfico dividindo em dois subplots para separar visualmente vendas de custos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (14, 16))

# Plot de vendas
for column in df.columns[1:4]:  # Selecionando apenas colunas de vendas
    ax1.plot(df['Mes'], df[column], marker = 'o', linestyle = '-', label = column)

ax1.set_title('Vendas por Mês')
ax1.set_ylabel('Valor das Vendas')
ax1.legend()
ax1.grid(True)

# Plot de custos
for column in df.columns[4:]:  # Selecionando apenas colunas de custos
    ax2.plot(df['Mes'], df[column], marker = 'x', linestyle = '--', label = column)

ax2.set_title('Custos por Mês')
ax2.set_xlabel('Mês')
ax2.set_ylabel('Valor dos Custos')
ax2.legend()
ax2.grid(True)
plt.show()

# %% [markdown]
# ## Visualização 6
#
# Problema: Ignorar a Legenda ou Torná-la Confusa.
#
# Erro: Deixar de incluir uma legenda clara ou utilizar descrições que não refletem corretamente os dados apresentados. Neste exemplo, embora o gráfico represente duas séries empilhadas correspondentes a “Grupo 1” e “Grupo 2”, a legenda foi definida de forma genérica como “Dados X” e “Dados Y”, comprometendo a interpretação e dificultando a identificação correta de cada categoria no gráfico.

# %%
# Dados de exemplo
categorias = ['Categoria A', 'Categoria B', 'Categoria C']
valores1 = [10, 20, 15]
valores2 = [25, 7, 18]

# Barras empilhadas
plt.figure(figsize = (10, 6))
plt.bar(categorias, valores1, color = 'blue', label = 'Grupo 1')
plt.bar(categorias, valores2, bottom = valores1, color = 'red', label = 'Grupo 2')

# Criando a legenda 
plt.legend(title = 'Legenda', labels = ['Dados X', 'Dados Y'])

# Labels
plt.title('Categorias x Valores')
plt.xlabel('\nCategorias')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# > Versão Corrigida:

# %%
# Dados de exemplo
categorias = ['Categoria A', 'Categoria B', 'Categoria C']
valores1 = [10, 20, 15]
valores2 = [25, 7, 18]

# Corrigindo o gráfico com uma legenda apropriada
plt.figure(figsize = (10, 6))
plt.bar(categorias, valores1, color = 'blue', label = 'Grupo 1')
plt.bar(categorias, valores2, bottom = valores1, color = 'red', label = 'Grupo 2')

# Legenda correta
plt.legend(title = 'Legenda')

plt.title('Categorias x Valores')
plt.xlabel('\nCategorias')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# ## Visualização 7
#
# Problema: Comparação Injusta e Desproporcional.
#
# Erro: Confrontar conjuntos de dados que não estão na mesma escala ou que deveriam ser normalizados antes da análise. Neste caso, comparar vendas de uma loja (em unidades) com visitantes de um site (em milhares) no mesmo gráfico, sem ajustes, cria uma falsa equivalência e pode levar a interpretações distorcidas sobre a relevância ou desempenho relativo de cada métrica.

# %%
# Dados de exemplo
meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril']
vendas = [950, 1050, 1100, 1150] 
visitantes = [4500, 4700, 4800, 5000]  

# Área de plotagem
fig, ax1 = plt.subplots(figsize = (10, 6))

# Gráfico de barras para vendas
ax1.bar(meses, vendas, color = 'g', label = 'Vendas (Loja A)')
ax1.set_xlabel('Mês')
ax1.set_ylabel('Vendas (Unidades)', color = 'g')

# Criando um segundo eixo y para os visitantes
ax2 = ax1.twinx()
ax2.plot(meses, visitantes, color = 'b', marker = 'o', linestyle = '-', label = 'Visitantes (Site B)')
ax2.set_ylabel('Visitantes (Milhares)', color = 'b')

# Título e legenda
plt.title('Vendas vs. Visitantes')
ax1.legend(loc = 'upper left')
ax2.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# > Versão Corrigida:

# %%
# Aplicando a transformação de log nas duas variáveis
vendas_log = np.log(vendas)
visitantes_log = np.log(visitantes)

# Área de plotagem com transformação de log
fig, ax1 = plt.subplots(figsize = (10, 6))

# Gráfico de barras para vendas com log
ax1.bar(meses, vendas_log, color = 'g', label = 'Vendas (Loja A) - Log')
ax1.set_xlabel('Mês')
ax1.set_ylabel('Log de Vendas (Unidades)', color = 'g')

# Criando um segundo eixo y para os visitantes com log
ax2 = ax1.twinx()
ax2.plot(meses, visitantes_log, color = 'b', marker = 'o', linestyle = '-', label = 'Visitantes (Site B) - Log')
ax2.set_ylabel('Log de Visitantes (Milhares)', color = 'b')

# Título e legenda
plt.title('Vendas vs. Visitantes (Log)')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.show()

# %%
# %reload_ext watermark
# %watermark -a "André Luiz Colombo"
# Out:
# Author: André Luiz Colombo

# %%
# %watermark -v -m
# Out:
# Python implementation: CPython
# Python version       : 3.13.5
# IPython version      : 9.4.0
#
# Compiler    : MSC v.1929 64 bit (AMD64)
# OS          : Windows
# Release     : 11
# Machine     : AMD64
# Processor   : AMD64 Family 23 Model 104 Stepping 1, AuthenticAMD
# CPU cores   : 12
# Architecture: 64bit

# %%
# %watermark --iversions
# Out:
# matplotlib: 3.10.3
# numpy     : 2.3.1
# pandas    : 2.3.1

# %% [markdown]
# # Fim
